# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshii009/MLT-colab-pracctice/blob/main/Linear_Regression2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Step 1: Importing library**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Step 2: Read the Data**

# %%
data = {"hours":[1,2,3,4,5],
        "marks":[50,60,80,90,100]}
df=pd.DataFrame(data)
print(df)
# Out:
#    hours  marks
# 0      1     50
# 1      2     60
# 2      3     80
# 3      4     90
# 4      5    100

# %%
x=df[["hours"]].values
y=df[["marks"]].values

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
slope=model.coef_[0]
intercept=model.intercept_

# %%
#"f-string" (formatted string literal) in Python
#.2f: This is a format specifier used within the curly braces of an f-string
print(f"Slope(m):{slope}")
print(f"Intercept(b):{intercept}")
print(f"Equatio of the regression line: y={slope[0]:.2f} x +{intercept[0]:.2f}")
# Out:
# Slope(m):[13.]
# Intercept(b):[37.]
# Equatio of the regression line: y=13.00 x +37.00

# %%
df['Predicted Marks']=model.predict(x)

# %%
df.head()
# Out:
#    hours  marks  Predicted Marks
# 0      1     50             50.0
# 1      2     60             63.0
# 2      3     80             76.0
# 3      4     90             89.0
# 4      5    100            102.0

# %% [markdown]
# **Visualizing**

# %%
plt.scatter(df['hours'],df['marks'],color='blue',label='Actual Marks')

# %% [markdown]
# plotting the equation

# %%
plt.plot(df['hours'],df['marks'],color='blue',label='Regression Line')
plt.xlabel('Hours studied')
plt.ylabel('Marks')
plt.title('Linear Regression: Hours vs Marks')
plt.legend()
plt.show()
